# %%
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
digits = datasets.load_digits()
X = digits.data
# X
y = digits.target
# y

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)
X_pca
# Out:
# array([[ -1.25946645, -21.27488348],
#        [  7.9576113 ,  20.76869896],
#        [  6.99192297,   9.95598641],
#        ...,
#        [ 10.8012837 ,   6.96025223],
#        [ -4.87210009, -12.42395362],
#        [ -0.34438963,  -6.36554919]], shape=(1797, 2))

# %%
# X_pca[:,1]

# %%
plt.scatter(X_pca[:,0],X_pca[:,1],c=y, cmap='jet',edgecolors='k')
plt.colorbar()
plt.title("PCA Visualization")
plt.show()

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(
    n_components=2,
    perplexity=30,
    max_iter=700,
    random_state=42
)

# %%
X_tsne = tsne.fit_transform(X)

# %%
X_tsne
# Out:
# array([[ -2.8586252, -45.605644 ],
#        [ 10.193736 ,   9.546045 ],
#        [-12.548242 ,  17.62276  ],
#        ...,
#        [ -5.3749967,   9.972571 ],
#        [-18.931734 , -13.768218 ],
#        [-12.895837 ,   6.5418477]], shape=(1797, 2), dtype=float32)

# %%
plt.scatter(X_tsne[:,0],X_tsne[:,1],c=y, cmap='jet', edgecolors='k')
plt.colorbar()
plt.title("TSNE Visualization")
plt.show()
